# %%
! pip install numpy pandas matplotlib seaborn scikit-learn tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\alyster alvin\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\alyster alvin\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\alyster alvin\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: seaborn in c:\users\alyster alvin\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: scikit-learn in c:\users\alyster alvin\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: tensorflow in c:\users\alyster alvin\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alyster alvin\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\alyster alvin\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.67.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: setuptools in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (63.4.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.28.1)
# Requirement already satisfied: keras>=3.5.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Collecting scipy>=1.0
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
#      ---------------------------------------- 46.2/46.2 MB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.37.1)
# Requirement already satisfied: optree in c:\users\alyster alvin\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: rich in c:\users\alyster alvin\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in c:\users\alyster alvin\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alyster alvin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alyster alvin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\alyster alvin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alyster alvin\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alyster alvin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.1
#     Uninstalling scipy-1.9.1:
#       Successfully uninstalled scipy-1.9.1
# Successfully installed scipy-1.13.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,InputLayer
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,classification_report,accuracy_score,average_precision_score

# %%
df = pd.read_csv('C:/Users/Alyster Alvin/Documents/Project/BP categorization/cardio_data_processed.csv')
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 68200  99993  19240       2     168    76.0    120     80            1     1
# 68201  99995  22601       1     158   126.0    140     90            2     2
# 68202  99996  19066       2     183   105.0    180     90            3     1
# 68203  99998  22431       1     163    72.0    135     80            1     2
# 68204  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  age_years        bmi  \
# 0          0     0       1       0         50  21.967120
# 1          0     0       1       1         55  34.927679
# 2          0     0       0       1         51  23.507805
# 3          0     0       1       1         48  28.710479
# 4          0     0       0       0         47  23.011177
# ...      ...   ...     ...     ...        ...        ...
# 68200      1     0       1       0         52  26.927438
# 68201      0     0       1       1         61  50.472681
# 68202      0     1       0       1         52  31.353579
# 68203      0     0       0       1         61  27.099251
# 68204      0     0       1       0         56  24.913495
#
#                 bp_category   bp_category_encoded
# 0      Hypertension Stage 1  Hypertension Stage 1
# 1      Hypertension Stage 2  Hypertension Stage 2
# 2      Hypertension Stage 1  Hypertension Stage 1
# 3      Hypertension Stage 2  Hypertension Stage 2
# 4                    Normal                Normal
# ...                     ...                   ...
# 68200  Hypertension Stage 1  Hypertension Stage 1
# 68201  Hypertension Stage 2  Hypertension Stage 2
# 68202  Hypertension Stage 2  Hypertension Stage 2
# 68203  Hypertension Stage 1  Hypertension Stage 1
# 68204  Hypertension Stage 1  Hypertension Stage 1
#
# [68205 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68205 entries, 0 to 68204
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   68205 non-null  int64
#  1   age                  68205 non-null  int64
#  2   gender               68205 non-null  int64
#  3   height               68205 non-null  int64
#  4   weight               68205 non-null  float64
#  5   ap_hi                68205 non-null  int64
#  6   ap_lo                68205 non-null  int64
#  7   cholesterol          68205 non-null  int64
#  8   gluc                 68205 non-null  int64
#  9   smoke                68205 non-null  int64
#  10  alco                 68205 non-null  int64
#  11  active               68205 non-null  int64
#  12  cardio               68205 non-null  int64
#  13  age_years            68205 non-null  int64
#  14  bmi                  68205 non-null  float64
#  15  bp_category          68205 non-null  object
#  16  bp_category_encoded  68205 non-null  object
# dtypes: float64(2), int64(13), object(2)
# memory usage: 8.8+ MB

# %%
df.isna().sum()
# Out:
# id                     0
# age                    0
# gender                 0
# height                 0
# weight                 0
# ap_hi                  0
# ap_lo                  0
# cholesterol            0
# gluc                   0
# smoke                  0
# alco                   0
# active                 0
# cardio                 0
# age_years              0
# bmi                    0
# bp_category            0
# bp_category_encoded    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Category distribution
plt.figure(figsize=(10,6))
df['bp_category'].hist(grid=False)
plt.title('Blood Pressure Category Distribution')
plt.xlabel('Blood Pressure Categories')
plt.ylabel('Number of patients')
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
#check age distribution
plt.figure(figsize=(10,6))
df['age_years'].hist(grid=False,bins=15)
plt.title("Age distribution")
plt.xlabel('Age (in years)')
plt.ylabel('Number of patients')
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
#no of patients based on gender
plt.figure(figsize=(10,6))
df['gender'].hist(grid=False)
plt.title("Gender distribution")
plt.xlabel('Gender')
plt.ylabel('Number of patients')
plt.xticks([1.05,1.95],['Female','Male'])
# Out:
# ([<matplotlib.axis.XTick at 0x1b5546f27b0>,
#   <matplotlib.axis.XTick at 0x1b5546f3380>],
#  [Text(1.05, 0, 'Female'), Text(1.95, 0, 'Male')])

# %%
#drop the bp_category_encoded or bp_category --> object datatype
df =df.drop('bp_category',axis=1)
#drop the id column
df = df.drop('id',axis=1)

# %%
#Apply ordinal encoder to labels to prep for ANN
bp_categories = ['Normal','Elevated','Hypertension Stage 1','Hypertension Stage 2']
enc = OrdinalEncoder()
df['bp_category_encoded']=enc.fit_transform(df[['bp_category_encoded']])

#Turn the encoded labels into integers
df['bp_category_encoded']=df['bp_category_encoded'].apply(lambda x: int(x))

# %%
#Split features and label
X = df.drop('bp_category_encoded',axis=1)
y = df['bp_category_encoded']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((54564, 14), (13641, 14), (54564,), (13641,))

# %%
#Apply the minmax scaler to the data for normalization
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score, average_precision_score

# Set random seed
tf.random.set_seed(42)

# Create model
model = Sequential([
    InputLayer(input_shape=(14,)),  # Corrected input_shape to be a tuple
    Dense(14, activation='relu'),
    Dense(14, activation='relu'),
    Dense(4, activation='softmax'),
])

# Compile the model
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# Fit the model
history = model.fit(X_train, y_train,
                    epochs=25,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7130 - loss: 0.7725 - val_accuracy: 0.8950 - val_loss: 0.3018
# Epoch 2/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9061 - loss: 0.2851 - val_accuracy: 0.9083 - val_loss: 0.2744
# Epoch 3/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9183 - loss: 0.2616 - val_accuracy: 0.9101 - val_loss: 0.2526
# Epoch 4/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9185 - loss: 0.2399 - val_accuracy: 0.9064 - val_loss: 0.2322
# Epoch 5/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9151 - loss: 0.2215 - val_accuracy: 0.9077 - val_loss: 0.2202
# Epoch 6/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9167 - loss: 0.2103 - val_accuracy: 0.9057 - val_loss: 0.2108
# Epoch 7/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9173 - loss: 0.1994 - val_accuracy: 0.9132 - val_loss: 0.1879
# Epoch 8/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9293 - loss: 0.1782 - val_accuracy: 0.9272 - val_loss: 0.1742
# Epoch 9/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9384 - loss: 0.1655 - val_accuracy: 0.9438 - val_loss: 0.1607
# Epoch 10/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9488 - loss: 0.1508 - val_accuracy: 0.9609 - val_loss: 0.1456
# Epoch 11/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9588 - loss: 0.1352 - val_accuracy: 0.9671 - val_loss: 0.1293
# Epoch 12/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9675 - loss: 0.1200 - val_accuracy: 0.9740 - val_loss: 0.1126
# Epoch 13/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9749 - loss: 0.1024 - val_accuracy: 0.9808 - val_loss: 0.0893
# Epoch 14/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9796 - loss: 0.0833 - val_accuracy: 0.9854 - val_loss: 0.0744
# Epoch 15/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9826 - loss: 0.0702 - val_accuracy: 0.9869 - val_loss: 0.0638
# Epoch 16/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9858 - loss: 0.0593 - val_accuracy: 0.9881 - val_loss: 0.0522
# Epoch 17/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9885 - loss: 0.0487 - val_accuracy: 0.9890 - val_loss: 0.0451
# Epoch 18/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9897 - loss: 0.0427 - val_accuracy: 0.9900 - val_loss: 0.0403
# Epoch 19/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9904 - loss: 0.0383 - val_accuracy: 0.9905 - val_loss: 0.0365
# Epoch 20/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9914 - loss: 0.0349 - val_accuracy: 0.9910 - val_loss: 0.0336
# Epoch 21/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9919 - loss: 0.0322 - val_accuracy: 0.9916 - val_loss: 0.0309
# Epoch 22/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9925 - loss: 0.0299 - val_accuracy: 0.9921 - val_loss: 0.0288
# Epoch 23/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9930 - loss: 0.0279 - val_accuracy: 0.9920 - val_loss: 0.0270
# Epoch 24/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9933 - loss: 0.0263 - val_accuracy: 0.9924 - val_loss: 0.0254
# Epoch 25/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9936 - loss: 0.0250 - val_accuracy: 0.9931 - val_loss: 0.0237

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 14)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 14)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            60 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,442 (5.64 KB)
#  Trainable params: 480 (1.88 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 962 (3.76 KB)

# %%
plot_model(model,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
#checking model training loss history
loss=history.history['loss']
val_loss=history.history['val_loss']
losses = pd.DataFrame({'loss':loss,'val_loss':val_loss})

#checking model training accuracy history
accuracy=history.history['accuracy']
val_accuracy=history.history['val_accuracy']
acc = pd.DataFrame({'accuracy':accuracy,'val_accuracy':val_accuracy})


losses.plot(title='Loss curve')
acc.plot(title='Accuracy curve')
# Out:
# <Axes: title={'center': 'Accuracy curve'}>

# %%
#Evaluating using model.evaluate
loss,acc = model.evaluate(X_test,y_test)
print(f"Model loss: {loss:.3f}")
print(f"Model accuracy: {acc*100:.2f}%")
# Out:
# 427/427 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9924 - loss: 0.0251
# Model loss: 0.024
# Model accuracy: 99.31%

# %%
#set random seed
tf.random.set_seed(42)

y_probs = model.predict(X_test)
y_preds = tf.argmax(y_probs,axis=1)
# Out:
# 427/427 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
#report + accuracy
acc_score=accuracy_score(y_test,y_preds)

print(classification_report(y_test,y_preds))
print(f'Accuracy is {acc_score*100:.2f}%')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       598
#            1       0.99      0.99      0.99      7924
#            2       0.99      0.99      0.99      3225
#            3       1.00      0.99      1.00      1894
#
#     accuracy                           0.99     13641
#    macro avg       0.99      0.99      0.99     13641
# weighted avg       0.99      0.99      0.99     13641
#
# Accuracy is 99.31%

# %%
#Making Confusion Matrix
cm = confusion_matrix(y_test,y_preds)

#using ConfusionMatrixDisplay to output a good confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=bp_categories)
disp.plot()
plt.title("Confusion Matrix")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Normal'),
#   Text(1, 0, 'Elevated'),
#   Text(2, 0, 'Hypertension Stage 1'),
#   Text(3, 0, 'Hypertension Stage 2')])

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr())
plt.title('Correlation between features')
# Out:
# Text(0.5, 1.0, 'Correlation between features')

# %%
plt.figure(figsize=(18,4))
df.corr()['bp_category_encoded'][:-1].sort_values(ascending = True).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Correlation to blood pressure categories')
plt.title('Features\' correlation to the label')
# Out:
# Text(0.5, 1.0, "Features' correlation to the label")
